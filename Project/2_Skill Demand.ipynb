# %%
#Turn off warning notification
import warnings
warnings.filterwarnings("ignore")

import datasets
datasets.logging.set_verbosity_error()

# %% [markdown]
# ### Import Libraries and Data

# %%
# Import library
import pandas as pd
import numpy as np
import ast
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

#Loading Dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)

# %% [markdown]
# ### Filter Data for Singapore

# %%
df_Singapore = df[df['job_country'] == 'Singapore']

# %% [markdown]
# ### Explode Skills

# %%
df_Singapore.dropna(subset='salary_year_avg')
# Out:
#                   job_title_short  \
# 3457                 Data Analyst
# 13079               Data Engineer
# 17105              Data Scientist
# 17301   Machine Learning Engineer
# 17843              Data Scientist
# ...                           ...
# 767681       Senior Data Engineer
# 769703               Data Analyst
# 772750             Data Scientist
# 778277               Data Analyst
# 778805               Data Analyst
#
#                                                 job_title job_location  \
# 3457    Session Lead (External Contractor) - Data Anal...    Singapore
# 13079                                       Data Engineer    Singapore
# 17105                              People Data Specialist    Singapore
# 17301   Binance Accelerator Program - SRE Engineer (Ma...    Singapore
# 17843                                Data Science Manager    Singapore
# ...                                                   ...          ...
# 767681                     Senior Engineer, Data Pipeline    Singapore
# 769703                           Institution Data Analyst    Singapore
# 772750                   Staff/Senior Risk Data Scientist    Singapore
# 778277                               Data Analyst, Mobile    Singapore
# 778805                                Carbon Data Analyst    Singapore
#
#                 job_via job_schedule_type  job_work_from_home search_location  \
# 3457    via Ai-Jobs.net         Part-time               False       Singapore
# 13079   via Ai-Jobs.net         Full-time               False       Singapore
# 17105   via Ai-Jobs.net         Full-time               False       Singapore
# 17301   via Ai-Jobs.net         Full-time               False       Singapore
# 17843   via Ai-Jobs.net         Full-time               False       Singapore
# ...                 ...               ...                 ...             ...
# 767681  via Ai-Jobs.net         Full-time               False       Singapore
# 769703  via Ai-Jobs.net         Full-time               False       Singapore
# 772750  via Ai-Jobs.net         Full-time               False       Singapore
# 778277  via Ai-Jobs.net         Full-time               False       Singapore
# 778805  via Ai-Jobs.net         Full-time               False       Singapore
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 3457   2023-08-08 13:28:55                   True                 False
# 13079  2023-02-28 13:15:34                  False                 False
# 17105  2023-07-07 13:16:21                  False                 False
# 17301  2023-03-28 14:09:12                  False                 False
# 17843  2023-08-10 14:04:16                  False                 False
# ...                    ...                    ...                   ...
# 767681 2023-04-14 01:31:17                  False                 False
# 769703 2023-06-13 02:01:17                  False                 False
# 772750 2023-01-11 01:42:20                  False                 False
# 778277 2023-08-25 05:39:34                  False                 False
# 778805 2023-05-16 06:24:32                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 3457     Singapore        year         100500.0              NaN
# 13079    Singapore        year          96773.0              NaN
# 17105    Singapore        year         109500.0              NaN
# 17301    Singapore        year          50400.0              NaN
# 17843    Singapore        year         183320.0              NaN
# ...            ...         ...              ...              ...
# 767681   Singapore        year          79200.0              NaN
# 769703   Singapore        year          57500.0              NaN
# 772750   Singapore        year         157500.0              NaN
# 778277   Singapore        year         111175.0              NaN
# 778805   Singapore        year          98500.0              NaN
#
#                          company_name  \
# 3457                    Udacity, Inc.
# 13079   Infosys Singapore & Australia
# 17105                      Toll Group
# 17301                         Binance
# 17843                       Airwallex
# ...                               ...
# 767681                       Motional
# 769703                            OKX
# 772750                      Airwallex
# 778277                             2K
# 778805                     Terrascope
#
#                                                job_skills  \
# 3457            [python, sql, numpy, pandas, zoom, slack]
# 13079                         [python, sql, aws, airflow]
# 17105                                                 NaN
# 17301    [java, scala, python, go, hadoop, spark, spring]
# 17843                 [r, python, matlab, sas, sas, spss]
# ...                                                   ...
# 767681  [python, sql, aws, docker, kubernetes, ansible...
# 769703                                                [r]
# 772750                                   [python, r, sql]
# 778277                          [r, python, sql, tableau]
# 778805                                       [sql, excel]
#
#                                           job_type_skills
# 3457    {'libraries': ['numpy', 'pandas'], 'programmin...
# 13079   {'cloud': ['aws'], 'libraries': ['airflow'], '...
# 17105                                                 NaN
# 17301   {'libraries': ['hadoop', 'spark', 'spring'], '...
# 17843   {'analyst_tools': ['sas', 'spss'], 'programmin...
# ...                                                   ...
# 767681  {'cloud': ['aws'], 'other': ['docker', 'kubern...
# 769703                             {'programming': ['r']}
# 772750            {'programming': ['python', 'r', 'sql']}
# 778277  {'analyst_tools': ['tableau'], 'programming': ...
# 778805  {'analyst_tools': ['excel'], 'programming': ['...
#
# [98 rows x 17 columns]
