# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df.job_posted_date = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Drop Missing Values (2.3.1) - Problem
#
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values. Display the first 5 rows of the cleaned DataFrame.

# %%
# df_copy = df.copy()
# df_cleaned = df_copy.dropna(subset=['salary_year_avg'])
# df_cleaned.head(5)

df_copied = df.copy()
df_copied = df_copied.dropna(subset = 'salary_year_avg')

df_copied.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# 92          Full-time                True    Illinois, United States
# 100         Full-time               False  California, United States
# 109         Full-time                True    Illinois, United States
#
#         job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28  2023-08-01 13:37:57                  False                 False
# 77  2023-06-26 14:22:54                  False                 False
# 92  2023-02-21 13:29:59                  False                  True
# 100 2023-07-31 13:01:18                  False                  True
# 109 2023-10-12 13:02:19                  False                  True
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28      Costa Rica        year         109500.0              NaN
# 77           Sudan        year         140000.0              NaN
# 92   United States        year         120000.0              NaN
# 100  United States        year         228222.0              NaN
# 109  United States        year          89000.0              NaN
#
#                         company_name  \
# 28                          Netskope
# 77                        Intelletec
# 92                      Apex Systems
# 100                           TikTok
# 109  Get It Recruit - Transportation
#
#                                             job_skills  \
# 28                                   ['gdpr', 'excel']
# 77   ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                   ['sql', 'python']
# 100                  ['sql', 'r', 'python', 'express']
# 109              ['python', 'r', 'alteryx', 'tableau']
#
#                                        job_type_skills
# 28   {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77   {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                  {'programming': ['sql', 'python']}
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %% [markdown]
# ## 🟩 Random Sample of DataFrame (2.3.2) - Problem
#
# Create a new DataFrame that is a random sample of 10% of the original DataFrame. Display the first 5 rows of the sampled DataFrame.

# %%
df_sample = df.sample(frac=0.1)

df_sample.head(5)
# Out:
#               job_title_short                                       job_title  \
# 289435          Data Engineer                                   Data Engineer
# 441350  Senior Data Scientist                           Senior Data Scientist
# 176171    Senior Data Analyst  Senior Data Analyst, Puffy - Powered By Qureos
# 362061           Data Analyst                       Internship Data Analytics
# 15576           Data Engineer                        Big Data Engineer Remote
#
#                             job_location             job_via  \
# 289435                    Birmingham, AL           via Nexxt
# 441350                   Morrisville, NC           via BeBee
# 176171  Abu Dhabi - United Arab Emirates        via LinkedIn
# 362061                  Antwerp, Belgium  via BeBee Belgique
# 15576          Thane, Maharashtra, India     via SimplyHired
#
#        job_schedule_type  job_work_from_home          search_location  \
# 289435         Full-time               False  Illinois, United States
# 441350         Full-time               False  New York, United States
# 176171               NaN               False     United Arab Emirates
# 362061        Internship               False                  Belgium
# 15576          Full-time               False                    India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 289435 2023-07-29 17:07:36                   True                 False
# 441350 2023-08-27 16:02:49                  False                 False
# 176171 2023-02-08 23:46:12                  False                 False
# 362061 2023-10-14 00:06:55                  False                 False
# 15576  2023-11-02 13:14:41                   True                 False
#
#                  job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 289435         United States         NaN              NaN              NaN
# 441350         United States         NaN              NaN              NaN
# 176171  United Arab Emirates         NaN              NaN              NaN
# 362061               Belgium         NaN              NaN              NaN
# 15576                  India         NaN              NaN              NaN
#
#                         company_name  \
# 289435                    TEKsystems
# 441350  ASRC Federal Holding Company
# 176171                        Qureos
# 362061            Robert Bosch NV/SA
# 15576                 Hinopak Motors
#
#                                              job_skills  \
# 289435                            ['azure', 'power bi']
# 441350        ['sql', 'r', 'python', 'oracle', 'excel']
# 176171  ['sql', 'excel', 'atlassian', 'asana', 'slack']
# 362061                                              NaN
# 15576                                ['nosql', 'spark']
#
#                                           job_type_skills
# 289435  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 441350  {'analyst_tools': ['excel'], 'cloud': ['oracle...
# 176171  {'analyst_tools': ['excel'], 'async': ['asana'...
# 362061                                                NaN
# 15576   {'libraries': ['spark'], 'programming': ['nosq...

# %% [markdown]
# ## 🟨 Fill Missing Salaries (2.3.3) - Problem
#
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. Display the first 5 rows of the altered DataFrame.

# %%
df_copied = df.copy()

#Calculating the median yearly salary
median_salary = df_copied.salary_year_avg.median()

#Fill the missing values in the salary_year_avg column
df_copied['salary_year_avg'] = df_copied['salary_year_avg'].fillna(median_salary)

df_copied.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
# 2                  False                 False        Germany         NaN
# 3                   True                 False  United States         NaN
# 4                  False                 False          Sudan         NaN
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0         115000.0              NaN          Boehringer Ingelheim
# 1         115000.0              NaN    Hewlett Packard Enterprise
# 2         115000.0              NaN      ALPHA Augmented Services
# 3         115000.0              NaN  Southwest Research Institute
# 4         115000.0              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                                NaN
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                                NaN
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
